# %%
import numpy as np
import pandas as pd
import seaborn as sns
#import Zbox as zb 
from scipy import stats
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams.update({'font.sans-serif': 'Arial',
                    'font.family': 'sans-serif',
                    'font.size': 12,
                    'lines.linewidth': 0.3})
import rstoolbox as rb
rb.utils.format_Ipython()
# Out:
# <style>
# table.dataframe, div.slick-cell {
#     font-family: monospace  !important;
# }
# div.q-grid-toolbar > button:nth-of-type(1) {
#     visibility: hidden;
# }
# div.q-grid-toolbar > button:nth-of-type(2) {
#     visibility: hidden;
# }
# </style>

# %%
silentfile = "SD_wt.minisilent"

# %%
df = rb.io.parse_rosetta_file(silentfile)
df.head()
# Out:
#     score   fa_atr  fa_rep   fa_sol  fa_intra_rep  fa_elec  pro_close  \
# 0  7.725  -196.506  56.791  113.937  0.626        -25.697   0.182
# 1  8.369  -216.707  53.434  129.074  0.627        -22.999   0.082
# 2  34.951 -197.927  66.635  120.411  0.660        -29.077   0.680
# 3 -11.232 -227.343  41.177  120.384  0.747        -21.339   0.111
# 4  20.321 -237.795  77.829  127.019  0.739        -25.399   0.379
#
#    hbond_sr_bb  hbond_lr_bb  hbond_bb_sc  hbond_sc  dslf_fa13    rama   omega  \
# 0 -2.140       -2.869       -3.886       -4.098    -0.888      13.649  9.130
# 1 -2.540       -8.750       -3.172       -3.218    -0.662      13.569  13.077
# 2 -2.495       -5.362       -6.634       -1.804    -1.189      22.103  16.999
# 3 -4.876       -8.053       -1.899       -2.827    -0.100      8.084   16.896
# 4 -4.852       -9.645       -4.519       -0.691    -0.635      16.050  17.376
#
#    fa_dun  p_aa_pp  yhh_planarity     ref  P_ni_disulfides_side  \
# ...

# %%
df2=df.drop(['description'],axis=1)
df2.head()
# Out:
#     score   fa_atr  fa_rep   fa_sol  fa_intra_rep  fa_elec  pro_close  \
# 0  7.725  -196.506  56.791  113.937  0.626        -25.697   0.182
# 1  8.369  -216.707  53.434  129.074  0.627        -22.999   0.082
# 2  34.951 -197.927  66.635  120.411  0.660        -29.077   0.680
# 3 -11.232 -227.343  41.177  120.384  0.747        -21.339   0.111
# 4  20.321 -237.795  77.829  127.019  0.739        -25.399   0.379
#
#    hbond_sr_bb  hbond_lr_bb  hbond_bb_sc  hbond_sc  dslf_fa13    rama   omega  \
# 0 -2.140       -2.869       -3.886       -4.098    -0.888      13.649  9.130
# 1 -2.540       -8.750       -3.172       -3.218    -0.662      13.569  13.077
# 2 -2.495       -5.362       -6.634       -1.804    -1.189      22.103  16.999
# 3 -4.876       -8.053       -1.899       -2.827    -0.100      8.084   16.896
# 4 -4.852       -9.645       -4.519       -0.691    -0.635      16.050  17.376
#
#    fa_dun  p_aa_pp  yhh_planarity     ref  P_ni_disulfides_side  \
# ...

# %%
numbers = list(range(1,6229))
newnames =[]
for e in numbers:
    newnames.append("S4_1.1."+str(e))

# %%
df2=df2.sort_values(by="score")
df2["score"].mean()
# Out:
# 76.5234481374438

# %%
df2['newname']=newnames

# %%
df2.head()
# Out:
#        score   fa_atr  fa_rep   fa_sol  fa_intra_rep  fa_elec  pro_close  \
# 1337 -57.888 -230.174  37.937  111.798  0.842        -21.125   0.045
# 1856 -54.326 -232.345  40.918  139.708  0.635        -33.147   0.891
# 935  -50.201 -236.131  47.186  125.101  0.660        -36.496   0.105
# 2018 -49.638 -242.748  36.744  125.375  0.819        -24.261   0.013
# 5210 -49.613 -223.251  33.640  117.470  0.721        -29.193   0.104
#
#       hbond_sr_bb  hbond_lr_bb  hbond_bb_sc  hbond_sc  dslf_fa13   rama  \
# 1337 -6.292       -9.045       -2.553       -3.066    -0.629     -0.326
# 1856 -6.291       -6.791       -3.721       -6.790    -0.415      3.948
# 935  -5.325       -11.927      -2.512       -4.519    -0.372      4.052
# 2018 -4.892       -7.551       -2.060       -5.403    -0.905      1.072
# 5210 -4.994       -12.854      -1.896       -2.650    -0.060      3.858
#
#        omega  fa_dun  p_aa_pp  yhh_planarity     ref  P_ni_disulfides_side  \
# ...

# %%
df3 = df2[
    (df2["rama"] < 2) &
    (df2["score"] < -40)&
    (df2["final_rmsd"] <2)
].sort_values(["score"],ascending=True)
df2.head()
# Out:
#        score   fa_atr  fa_rep   fa_sol  fa_intra_rep  fa_elec  pro_close  \
# 1337 -57.888 -230.174  37.937  111.798  0.842        -21.125   0.045
# 1856 -54.326 -232.345  40.918  139.708  0.635        -33.147   0.891
# 935  -50.201 -236.131  47.186  125.101  0.660        -36.496   0.105
# 2018 -49.638 -242.748  36.744  125.375  0.819        -24.261   0.013
# 5210 -49.613 -223.251  33.640  117.470  0.721        -29.193   0.104
#
#       hbond_sr_bb  hbond_lr_bb  hbond_bb_sc  hbond_sc  dslf_fa13   rama  \
# 1337 -6.292       -9.045       -2.553       -3.066    -0.629     -0.326
# 1856 -6.291       -6.791       -3.721       -6.790    -0.415      3.948
# 935  -5.325       -11.927      -2.512       -4.519    -0.372      4.052
# 2018 -4.892       -7.551       -2.060       -5.403    -0.905      1.072
# 5210 -4.994       -12.854      -1.896       -2.650    -0.060      3.858
#
#        omega  fa_dun  p_aa_pp  yhh_planarity     ref  P_ni_disulfides_side  \
# ...

# %%
export_csv = df2.to_csv ('/Users/cheyang/Desktop/S4_1_scores.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %%
export_csv = df2.to_csv ('/Users/cheyang/Desktop/S4_1_best.csv', index = None, header=True) #Don't forget to add '.csv' at the end of the path
