# %%
import numpy as np
import pandas as pd
import seaborn as sns
#import Zbox as zb 
from scipy import stats
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams.update({'font.sans-serif': 'Arial',
                    'font.family': 'sans-serif',
                    'font.size': 12,
                    'lines.linewidth': 0.3})
import rstoolbox as rb
import plotly.graph_objs as go
pd.set_option('display.max_columns', None)
rb.utils.format_Ipython()
# Out:
# <style>
# table.dataframe, div.slick-cell {
#     font-family: monospace  !important;
# }
# div.q-grid-toolbar > button:nth-of-type(1) {
#     visibility: hidden;
# }
# div.q-grid-toolbar > button:nth-of-type(2) {
#     visibility: hidden;
# }
# </style>

# %%
silentfile = "/Users/cheyang/Sandbox/trivalent_cocktail/denovo_design/DNSIV/design/siteIV_bb3_design/siteIV_bb3_minisilent.gz"

# %%
df = rb.io.parse_rosetta_file(silentfile)
df.head()
# Out:
#      score   fa_atr  fa_rep   fa_sol  fa_intra_atr_xover4  \
# 0 -115.577 -256.903  25.183  217.362 -14.934
# 1 -115.466 -255.505  23.185  200.269 -16.702
# 2 -104.172 -248.849  23.487  210.326 -14.687
# 3 -108.466 -246.544  22.930  214.590 -16.787
# 4 -103.391 -251.736  23.637  208.931 -16.525
#
#    fa_intra_rep_xover4  fa_intra_sol_xover4  lk_ball  lk_ball_iso  \
# 0  6.837                12.732               106.457 -115.798
# 1  6.679                13.289               100.885 -109.575
# 2  5.984                11.828               101.821 -112.520
# 3  5.882                14.625               105.276 -111.885
# 4  9.010                14.164               107.732 -112.148
#
#    lk_ball_bridge  lk_ball_bridge_uncpl  fa_elec  fa_intra_elec  pro_close  \
# 0 -1.161          -3.200                -99.752  -19.446         0.868
# 1 -1.420          -2.997                -95.228  -22.262         0.204
# 2 -1.623          -3.416                -91.288  -18.054         0.206
# ...

# %%
df2=df.drop(['description'],axis=1)
df2.head()
# Out:
#      score   fa_atr  fa_rep   fa_sol  fa_intra_atr_xover4  \
# 0 -115.577 -256.903  25.183  217.362 -14.934
# 1 -115.466 -255.505  23.185  200.269 -16.702
# 2 -104.172 -248.849  23.487  210.326 -14.687
# 3 -108.466 -246.544  22.930  214.590 -16.787
# 4 -103.391 -251.736  23.637  208.931 -16.525
#
#    fa_intra_rep_xover4  fa_intra_sol_xover4  lk_ball  lk_ball_iso  \
# 0  6.837                12.732               106.457 -115.798
# 1  6.679                13.289               100.885 -109.575
# 2  5.984                11.828               101.821 -112.520
# 3  5.882                14.625               105.276 -111.885
# 4  9.010                14.164               107.732 -112.148
#
#    lk_ball_bridge  lk_ball_bridge_uncpl  fa_elec  fa_intra_elec  pro_close  \
# 0 -1.161          -3.200                -99.752  -19.446         0.868
# 1 -1.420          -2.997                -95.228  -22.262         0.204
# 2 -1.623          -3.416                -91.288  -18.054         0.206
# ...

# %%
len(df2)
# Out:
# 2560

# %%
numbers = list(range(1,2561))
description =[]
for e in numbers:
    description.append("siteIV_bb1_."+str(e))

# %%
df2['description']=description
df2.head()
# Out:
#      score   fa_atr  fa_rep   fa_sol  fa_intra_atr_xover4  \
# 0 -115.577 -256.903  25.183  217.362 -14.934
# 1 -115.466 -255.505  23.185  200.269 -16.702
# 2 -104.172 -248.849  23.487  210.326 -14.687
# 3 -108.466 -246.544  22.930  214.590 -16.787
# 4 -103.391 -251.736  23.637  208.931 -16.525
#
#    fa_intra_rep_xover4  fa_intra_sol_xover4  lk_ball  lk_ball_iso  \
# 0  6.837                12.732               106.457 -115.798
# 1  6.679                13.289               100.885 -109.575
# 2  5.984                11.828               101.821 -112.520
# 3  5.882                14.625               105.276 -111.885
# 4  9.010                14.164               107.732 -112.148
#
#    lk_ball_bridge  lk_ball_bridge_uncpl  fa_elec  fa_intra_elec  pro_close  \
# 0 -1.161          -3.200                -99.752  -19.446         0.868
# 1 -1.420          -2.997                -95.228  -22.262         0.204
# 2 -1.623          -3.416                -91.288  -18.054         0.206
# ...

# %%
df3 = df2[
    (df2["RMSD"] < 1.5) &
    (df2["score"] < -100)&
    (df2["match_probability"] > 0.75)&
    (df2["pack_threshold"] < 0.35)
].sort_values(["score"],ascending=True)
df3.head(100)
# Out:
#         score   fa_atr  fa_rep   fa_sol  fa_intra_atr_xover4  \
# 1231 -134.929 -271.662  24.515  216.445 -18.534
# 423  -124.348 -258.123  24.139  197.706 -15.970
# 1141 -123.360 -261.439  26.269  189.055 -16.563
# 1288 -119.520 -254.625  25.898  192.516 -15.251
# 191  -117.437 -261.621  27.011  199.474 -17.763
# 1517 -115.559 -261.327  26.803  224.400 -17.271
# 1330 -115.544 -249.655  25.009  206.336 -15.596
# 1747 -115.324 -262.501  26.312  206.146 -16.809
# 2381 -114.731 -255.693  28.024  202.293 -15.945
# 1995 -113.057 -245.751  28.583  197.104 -14.138
# 1228 -112.895 -261.368  29.126  196.434 -17.606
# 712  -110.829 -254.758  25.577  199.158 -17.379
# 1279 -110.732 -264.227  25.367  211.890 -18.646
# 1281 -110.214 -269.783  26.561  218.860 -18.841
# 2366 -109.200 -265.622  28.874  207.750 -17.338
# 2357 -106.525 -256.156  26.611  212.300 -17.199
# 2324 -103.396 -262.817  28.894  206.185 -18.388
# 92   -101.057 -254.868  24.062  204.129 -18.751
#
# ...

# %%
export_csv = df3.to_csv ('/Users/cheyang/Desktop/S4_2_bb3_best.csv', index = None, header=True)
