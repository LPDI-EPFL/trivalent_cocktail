# %%
import numpy as np
import pandas as pd
import seaborn as sns
#import Zbox as zb 
from scipy import stats
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams.update({'font.sans-serif': 'Arial',
                    'font.family': 'sans-serif',
                    'font.size': 12,
                    'lines.linewidth': 0.3})
import rstoolbox as rb
import plotly.graph_objs as go
pd.set_option('display.max_columns', None)
rb.utils.format_Ipython()
# Out:
# <style>
# table.dataframe, div.slick-cell {
#     font-family: monospace  !important;
# }
# div.q-grid-toolbar > button:nth-of-type(1) {
#     visibility: hidden;
# }
# div.q-grid-toolbar > button:nth-of-type(2) {
#     visibility: hidden;
# }
# </style>

# %%
silentfile = "/Users/cheyang/Sandbox/trivalent_cocktail/denovo_design/DNSIV/design/siteIV_bb2_design/siteIV_bb2_minisilent.gz"

# %%
df = rb.io.parse_rosetta_file(silentfile)
df.head()
# Out:
#      score   fa_atr  fa_rep   fa_sol  fa_intra_atr_xover4  \
# 0 -106.827 -233.792  24.731  165.511 -15.967
# 1 -107.984 -233.051  21.104  168.820 -15.004
# 2 -102.509 -231.624  23.105  160.642 -16.110
# 3 -103.753 -236.824  23.633  189.444 -15.688
# 4 -107.464 -232.525  21.283  188.988 -15.016
#
#    fa_intra_rep_xover4  fa_intra_sol_xover4  lk_ball  lk_ball_iso  \
# 0  7.855                13.509               92.715  -97.827
# 1  7.310                12.651               92.646  -98.317
# 2  9.473                12.667               87.878  -96.041
# 3  7.577                13.961               101.160 -104.380
# 4  6.547                12.292               93.380  -101.326
#
#    lk_ball_bridge  lk_ball_bridge_uncpl  fa_elec  fa_intra_elec  pro_close  \
# 0 -0.924          -2.822                -78.846  -23.517         0.019
# 1 -0.805          -2.992                -72.707  -24.768         0.057
# 2 -0.827          -2.632                -70.392  -22.956         0.058
# ...

# %%
df2=df.drop(['description'],axis=1)
df2.head()
# Out:
#      score   fa_atr  fa_rep   fa_sol  fa_intra_atr_xover4  \
# 0 -106.827 -233.792  24.731  165.511 -15.967
# 1 -107.984 -233.051  21.104  168.820 -15.004
# 2 -102.509 -231.624  23.105  160.642 -16.110
# 3 -103.753 -236.824  23.633  189.444 -15.688
# 4 -107.464 -232.525  21.283  188.988 -15.016
#
#    fa_intra_rep_xover4  fa_intra_sol_xover4  lk_ball  lk_ball_iso  \
# 0  7.855                13.509               92.715  -97.827
# 1  7.310                12.651               92.646  -98.317
# 2  9.473                12.667               87.878  -96.041
# 3  7.577                13.961               101.160 -104.380
# 4  6.547                12.292               93.380  -101.326
#
#    lk_ball_bridge  lk_ball_bridge_uncpl  fa_elec  fa_intra_elec  pro_close  \
# 0 -0.924          -2.822                -78.846  -23.517         0.019
# 1 -0.805          -2.992                -72.707  -24.768         0.057
# 2 -0.827          -2.632                -70.392  -22.956         0.058
# ...

# %%
len(df2)
# Out:
# 455

# %%
numbers = list(range(1,456))
description =[]
for e in numbers:
    description.append("siteIV_bb2_."+str(e))

# %%
df2['description']=description
df2.head()
# Out:
#      score   fa_atr  fa_rep   fa_sol  fa_intra_atr_xover4  \
# 0 -106.827 -233.792  24.731  165.511 -15.967
# 1 -107.984 -233.051  21.104  168.820 -15.004
# 2 -102.509 -231.624  23.105  160.642 -16.110
# 3 -103.753 -236.824  23.633  189.444 -15.688
# 4 -107.464 -232.525  21.283  188.988 -15.016
#
#    fa_intra_rep_xover4  fa_intra_sol_xover4  lk_ball  lk_ball_iso  \
# 0  7.855                13.509               92.715  -97.827
# 1  7.310                12.651               92.646  -98.317
# 2  9.473                12.667               87.878  -96.041
# 3  7.577                13.961               101.160 -104.380
# 4  6.547                12.292               93.380  -101.326
#
#    lk_ball_bridge  lk_ball_bridge_uncpl  fa_elec  fa_intra_elec  pro_close  \
# 0 -0.924          -2.822                -78.846  -23.517         0.019
# 1 -0.805          -2.992                -72.707  -24.768         0.057
# 2 -0.827          -2.632                -70.392  -22.956         0.058
# ...

# %%
df3 = df2[
    (df2["RMSD"] < 1) &
    (df2["score"] < -100)&
    (df2["match_probability"] > 0.75)&
    (df2["pack_threshold"] < 0.4)
].sort_values(["score"],ascending=True)
df3.head(100)
# Out:
#        score   fa_atr  fa_rep   fa_sol  fa_intra_atr_xover4  \
# 416 -110.373 -242.030  22.046  188.632 -16.671
# 71  -109.958 -236.476  20.862  171.723 -15.791
# 310 -109.882 -239.248  21.201  175.721 -16.729
# 252 -109.507 -232.463  21.489  179.799 -15.539
# 329 -107.521 -233.187  23.092  167.140 -16.720
# 304 -106.227 -235.744  23.756  175.715 -16.776
# 318 -106.194 -234.558  22.887  184.951 -16.514
# 247 -105.755 -225.486  24.506  163.762 -14.093
# 171 -105.004 -236.989  21.789  176.949 -16.080
# 299 -104.751 -234.393  22.949  168.676 -15.742
# 184 -104.480 -225.845  21.842  166.307 -14.420
# 5   -104.211 -228.965  22.543  168.755 -14.949
# 178 -103.117 -228.821  20.807  184.892 -15.223
#
#      fa_intra_rep_xover4  fa_intra_sol_xover4  lk_ball  lk_ball_iso  \
# 416  7.041                15.575               96.502  -103.623
# 71   8.768                12.566               92.677  -99.692
# 310  9.412                14.882               92.018  -99.667
# ...

# %%
export_csv = df3.to_csv ('/Users/cheyang/Desktop/S4_2_bb2_best.csv', index = None, header=True)
