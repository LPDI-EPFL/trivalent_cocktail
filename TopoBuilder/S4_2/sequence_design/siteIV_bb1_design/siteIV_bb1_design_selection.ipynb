# %%
import numpy as np
import pandas as pd
import seaborn as sns
#import Zbox as zb 
from scipy import stats
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.rcParams['svg.fonttype'] = 'none'
plt.rcParams.update({'font.sans-serif': 'Arial',
                    'font.family': 'sans-serif',
                    'font.size': 12,
                    'lines.linewidth': 0.3})
import rstoolbox as rb
import plotly.graph_objs as go
pd.set_option('display.max_columns', None)
rb.utils.format_Ipython()
# Out:
# <style>
# table.dataframe, div.slick-cell {
#     font-family: monospace  !important;
# }
# div.q-grid-toolbar > button:nth-of-type(1) {
#     visibility: hidden;
# }
# div.q-grid-toolbar > button:nth-of-type(2) {
#     visibility: hidden;
# }
# </style>

# %%
silentfile = "/Users/cheyang/Sandbox/trivalent_cocktail/denovo_design/DNSIV/design/siteIV_bb1_design/siteIV_bb1_minisilent.gz"

# %%
df = rb.io.parse_rosetta_file(silentfile)
df.head()
# Out:
#      score   fa_atr  fa_rep   fa_sol  fa_intra_atr_xover4  \
# 0 -102.839 -232.749  27.578  183.257 -17.026
# 1 -97.200  -237.282  28.076  170.789 -18.487
# 2 -96.048  -233.004  28.626  171.511 -16.300
# 3 -97.482  -229.344  26.531  175.520 -15.800
# 4 -86.516  -239.922  34.364  158.392 -17.451
#
#    fa_intra_rep_xover4  fa_intra_sol_xover4  lk_ball  lk_ball_iso  \
# 0  7.885                12.860               95.945  -99.557
# 1  6.822                12.290               89.355  -97.456
# 2  9.342                12.528               90.887  -96.748
# 3  7.219                12.545               92.471  -95.831
# 4  7.421                12.824               88.528  -95.361
#
#    lk_ball_bridge  lk_ball_bridge_uncpl  fa_elec  fa_intra_elec  pro_close  \
# 0 -0.756          -1.906                -96.439  -20.180         0.127
# 1 -1.096          -2.160                -79.054  -17.882         0.113
# 2 -1.118          -2.174                -84.480  -21.326         0.154
# ...

# %%
df2=df.drop(['description'],axis=1)
df2.head()
# Out:
#      score   fa_atr  fa_rep   fa_sol  fa_intra_atr_xover4  \
# 0 -102.839 -232.749  27.578  183.257 -17.026
# 1 -97.200  -237.282  28.076  170.789 -18.487
# 2 -96.048  -233.004  28.626  171.511 -16.300
# 3 -97.482  -229.344  26.531  175.520 -15.800
# 4 -86.516  -239.922  34.364  158.392 -17.451
#
#    fa_intra_rep_xover4  fa_intra_sol_xover4  lk_ball  lk_ball_iso  \
# 0  7.885                12.860               95.945  -99.557
# 1  6.822                12.290               89.355  -97.456
# 2  9.342                12.528               90.887  -96.748
# 3  7.219                12.545               92.471  -95.831
# 4  7.421                12.824               88.528  -95.361
#
#    lk_ball_bridge  lk_ball_bridge_uncpl  fa_elec  fa_intra_elec  pro_close  \
# 0 -0.756          -1.906                -96.439  -20.180         0.127
# 1 -1.096          -2.160                -79.054  -17.882         0.113
# 2 -1.118          -2.174                -84.480  -21.326         0.154
# ...

# %%
len(df2)
# Out:
# 351

# %%
numbers = list(range(1,352))
description =[]
for e in numbers:
    description.append("siteIV_bb1_."+str(e))

# %%
df2['description']=description
df2.head()
# Out:
#      score   fa_atr  fa_rep   fa_sol  fa_intra_atr_xover4  \
# 0 -102.839 -232.749  27.578  183.257 -17.026
# 1 -97.200  -237.282  28.076  170.789 -18.487
# 2 -96.048  -233.004  28.626  171.511 -16.300
# 3 -97.482  -229.344  26.531  175.520 -15.800
# 4 -86.516  -239.922  34.364  158.392 -17.451
#
#    fa_intra_rep_xover4  fa_intra_sol_xover4  lk_ball  lk_ball_iso  \
# 0  7.885                12.860               95.945  -99.557
# 1  6.822                12.290               89.355  -97.456
# 2  9.342                12.528               90.887  -96.748
# 3  7.219                12.545               92.471  -95.831
# 4  7.421                12.824               88.528  -95.361
#
#    lk_ball_bridge  lk_ball_bridge_uncpl  fa_elec  fa_intra_elec  pro_close  \
# 0 -0.756          -1.906                -96.439  -20.180         0.127
# 1 -1.096          -2.160                -79.054  -17.882         0.113
# 2 -1.118          -2.174                -84.480  -21.326         0.154
# ...

# %%
df3 = df2[
    (df2["RMSD"] < 1) &
    (df2["score"] < -90)&
    (df2["match_probability"] > 0.75)&
    (df2["pack_threshold"] < 0.35)
].sort_values(["score"],ascending=True)
df3.head(100)
# Out:
#        score   fa_atr  fa_rep   fa_sol  fa_intra_atr_xover4  \
# 251 -114.438 -235.267  25.843  182.489 -17.256
# 198 -112.843 -240.559  29.463  171.932 -16.080
# 149 -111.006 -246.586  28.586  167.431 -20.243
# 336 -110.809 -236.883  25.663  183.818 -16.833
# 194 -108.848 -239.225  28.345  181.958 -17.374
# 312 -108.528 -231.791  26.913  176.456 -17.984
# 208 -107.736 -231.348  24.283  175.367 -17.300
# 217 -105.303 -238.498  28.370  178.985 -17.737
# 256 -103.482 -225.617  26.238  168.438 -15.198
# 230 -103.457 -231.425  25.389  175.760 -15.528
# 348 -99.002  -221.353  23.505  171.788 -16.536
# 124 -90.113  -232.646  26.818  174.622 -19.311
#
#      fa_intra_rep_xover4  fa_intra_sol_xover4  lk_ball  lk_ball_iso  \
# 251  7.797                14.902               93.545  -99.076
# 198  8.311                12.157               94.780  -98.810
# 149  8.701                11.896               91.281  -98.240
# 336  6.897                12.963               94.024  -99.742
# ...

# %%
export_csv = df3.to_csv ('/Users/cheyang/Desktop/S4_2_bb1_best.csv', index = None, header=True)
